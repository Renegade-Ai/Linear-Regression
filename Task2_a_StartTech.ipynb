# %%
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('/content/task 1.csv')
train.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0        NaN        NaN        NaN        NaN           NaN
# 1      S.No.    College       Role  City type  Previous CTC
# 2          1     Tier 1    Manager  Non-Metro    55,523.00
# 3          2     Tier 2  Executive      Metro    57,081.00
# 4          3     Tier 2  Executive      Metro    60,347.00
#
#              Unnamed: 5        Unnamed: 6    Unnamed: 7    Unnamed: 8
# 0                   NaN               NaN           NaN           NaN
# 1  Previous job changes  Graduation marks  Exp (Months)           CTC
# 2                     3                66            19    71,406.58
# 3                     1                84            18    68,005.87
# 4                     2                52            28    76,764.02

# %%
test = pd.read_csv('/content/task1 again.csv')
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  ...  \
# 0           0         55523                     3                66  ...
# 1           1         57081                     1                84  ...
# 2           1         60347                     2                52  ...
# 3           1         49010                     2                81  ...
# 4           1         57879                     4                74  ...
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# ...

# %%
test.shape
# Out:
# (1338, 24)

# %%
train.shape
# Out:
# (1340, 9)

# %%
test.iloc[: , 12:-1]
# Out:
#       Predicted CTC  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN  32438.76192  4659.731658
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 1333            NaN          NaN          NaN          NaN          NaN
# 1334            NaN          NaN          NaN          NaN          NaN
# 1335            NaN          NaN          NaN          NaN          NaN
# 1336            NaN          NaN          NaN          NaN          NaN
# 1337            NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# ...

# %%
test.drop( test.iloc[: , 12:] , axis = 1 , inplace = True)
test.shape
# Out:
# (1338, 12)

# %%
train.columns = train.iloc[1]

# %%
train.head()
# Out:
# 1  S.No.  College       Role  City type  Previous CTC  Previous job changes  \
# 0    NaN      NaN        NaN        NaN           NaN                   NaN
# 1  S.No.  College       Role  City type  Previous CTC  Previous job changes
# 2      1   Tier 1    Manager  Non-Metro    55,523.00                      3
# 3      2   Tier 2  Executive      Metro    57,081.00                      1
# 4      3   Tier 2  Executive      Metro    60,347.00                      2
#
# 1  Graduation marks  Exp (Months)           CTC
# 0               NaN           NaN           NaN
# 1  Graduation marks  Exp (Months)           CTC
# 2                66            19    71,406.58
# 3                84            18    68,005.87
# 4                52            28    76,764.02

# %%
train.drop(labels = [0,1] , axis = 0 , inplace = True)
train.head(2)
# Out:
# 1 S.No. College       Role  City type  Previous CTC Previous job changes  \
# 2     1  Tier 1    Manager  Non-Metro    55,523.00                     3
# 3     2  Tier 2  Executive      Metro    57,081.00                     1
#
# 1 Graduation marks Exp (Months)           CTC
# 2               66           19    71,406.58
# 3               84           18    68,005.87

# %%
test.head(2)
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
#
#     Actual CTC
# 0  71406.57653
# 1  68005.87063

# %%
print( train.shape , test.shape)
# Out:
# (1338, 9) (1338, 12)

# %%
train.drop( train.iloc[: ,0:1], axis = 1 , inplace = True)
train.head(1)
# Out:
# 1 College     Role  City type  Previous CTC Previous job changes  \
# 2  Tier 1  Manager  Non-Metro    55,523.00                     3
#
# 1 Graduation marks Exp (Months)           CTC
# 2               66           19    71,406.58

# %%
test.head(1)
# Out:
#   College     Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1  Manager  Non-Metro           1           0             1
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
#
#     Actual CTC
# 0  71406.57653

# %%
train['College'].mask(train['College'] == 'Tier 1' ,3, inplace = True)
train['College'].mask(train['College'] == 'Tier 2' ,2, inplace = True)
train['College'].mask(train['College'] == 'Tier 3' ,1, inplace = True)

train['Role'].mask(train['Role'] == 'Manager' ,1, inplace = True)
train['Role'].mask(train['Role'] == 'Executive' ,2, inplace = True)

# %%
test['College'].mask(test['College'] == 'Tier 1' ,3, inplace = True)
test['College'].mask(test['College'] == 'Tier 2' ,2, inplace = True)
test['College'].mask(test['College'] == 'Tier 3' ,1, inplace = True)

# %%
test['Role'].mask(test['Role'] == 'Manager' ,1, inplace = True)
test['Role'].mask(test['Role'] == 'Executive' ,2, inplace = True)

# %%
train['College'].unique()
# Out:
# array([3, 2, 1], dtype=object)

# %%
train['Role'].unique()
# Out:
# array([1, 2], dtype=object)

# %%
test['Role'].unique()
# Out:
# array([1, 2], dtype=object)

# %%
train['City type'].unique()
# Out:
# array(['Non-Metro', 'Metro'], dtype=object)

# %%
one_hot = pd.get_dummies(train['City type'])
train.drop('City type' , axis = 1 , inplace = True)
train = train.join(one_hot)

# %%
one_hot = pd.get_dummies(test['City type'])
test.drop('City type' , axis = 1 , inplace = True)
test = test.join(one_hot)

# %%
train.head(2)
# Out:
#   College Role  Previous CTC Previous job changes Graduation marks  \
# 2       3    1    55,523.00                     3               66
# 3       2    2    57,081.00                     1               84
#
#   Exp (Months)           CTC  Metro  Non-Metro
# 2           19    71,406.58       0          1
# 3           18    68,005.87       1          0

# %%
test.head(2)
# Out:
#   College Role  College_T1  College_T2  Role_Manager  City_Metro  \
# 0       3    1           1           0             1           0
# 1       2    2           0           1             0           1
#
#    previous CTC  previous job changes  Graduation marks  Exp   Actual CTC  \
# 0         55523                     3                66   19  71406.57653
# 1         57081                     1                84   18  68005.87063
#
#    Metro  Non-Metro
# 0      0          1
# 1      1          0

# %%
# from sklearn.preprocessing import LabelEncoder
# lb = LabelEncoder()

# train['College'] = lb.fit_transform(train['College'])
# train['Role'] = lb.fit_transform(train['Role'])
# train['City type'] = lb.fit_transform(train['City type'])

# train.head(2)

# %%
# test['College'] = lb.fit_transform(test['College'])
# test['Role'] = lb.fit_transform(test['Role'])
# test['City type'] = lb.fit_transform(test['City type'])

# %%
test.drop(test.iloc[:,2:6] , axis = 1 , inplace = True)

# %%
test.head(1)
# Out:
#   College Role  previous CTC  previous job changes  Graduation marks  Exp  \
# 0       3    1         55523                     3                66   19
#
#     Actual CTC  Metro  Non-Metro
# 0  71406.57653      0          1

# %%
train.head(1)
# Out:
#   College Role  Previous CTC Previous job changes Graduation marks  \
# 2       3    1    55,523.00                     3               66
#
#   Exp (Months)           CTC  Metro  Non-Metro
# 2           19    71,406.58       0          1

# %%
print(train.shape , test.shape)
# Out:
# (1338, 9) (1338, 9)

# %%
train.dtypes
# Out:
# College                 object
# Role                    object
# Previous CTC            object
# Previous job changes    object
# Graduation marks        object
# Exp (Months)            object
# CTC                     object
# Metro                    uint8
# Non-Metro                uint8
# dtype: object

# %%
train['Previous CTC'] = train['Previous CTC'].str.replace(',','')
train['CTC'] = train['CTC'].str.replace(',','')

# %%
train['Previous CTC'] = train['Previous CTC'].astype(float)

# %%
train['Previous job changes'] = train['Previous job changes'].astype(float)
train['Graduation marks'] = train['Graduation marks'].astype(float)
train['Exp (Months)'] = train['Exp (Months)'].astype(float)

# %%
train.dtypes
# Out:
# College                  object
# Role                     object
# Previous CTC            float64
# Previous job changes    float64
# Graduation marks        float64
# Exp (Months)            float64
# CTC                      object
# Metro                     uint8
# Non-Metro                 uint8
# dtype: object

# %%
train.head(1)
# Out:
#   College Role  Previous CTC  Previous job changes  Graduation marks  \
# 2       3    1       55523.0                   3.0              66.0
#
#    Exp (Months)          CTC  Metro  Non-Metro
# 2          19.0    71406.58       0          1

# %%
def Outlier1(data):
    threshold=3
    for i in range(len(data.columns)):
        X=data.iloc[:,i]
        outlier=[]
        
        mean_data=np.mean(X)
        print(mean_data)
        std_data=np.std(X)
        print(std_data)
        for j in X:
            z_score=(j-mean_data)/std_data
            if np.abs(z_score)>threshold:
                outlier.append(j)
        for j in outlier:
            data=data[data[data.columns[i]]!=j]
    return data

# %%
# train=Outlier1(train)

# %%
df_train = train
df_test = test

# %%
from sklearn.preprocessing import MinMaxScaler
# define standard scaler
scaler = MinMaxScaler()
# transform data
train = scaler.fit_transform(train)  

test = scaler.fit_transform(test)

# %%
train = pd.DataFrame(train, columns = df_train.columns)
train.head(3)
# Out:
#    College  Role  Previous CTC  Previous job changes  Graduation marks  \
# 0      1.0   0.0      0.452897              0.666667              0.62
# 1      0.5   1.0      0.490970              0.000000              0.98
# 2      0.5   1.0      0.570783              0.333333              0.34
#
#    Exp (Months)       CTC  Metro  Non-Metro
# 0      0.021739  0.261181    0.0        1.0
# 1      0.000000  0.212873    1.0        0.0
# 2      0.217391  0.337284    1.0        0.0

# %%
test = pd.DataFrame(test, columns = df_test.columns)
test.head(3)
# Out:
#    College  Role  previous CTC  previous job changes  Graduation marks  \
# 0      1.0   0.0      0.452897              0.666667              0.62
# 1      0.5   1.0      0.490970              0.000000              0.98
# 2      0.5   1.0      0.570783              0.333333              0.34
#
#         Exp  Actual CTC  Metro  Non-Metro
# 0  0.021739    0.261181    0.0        1.0
# 1  0.000000    0.212873    1.0        0.0
# 2  0.217391    0.337284    1.0        0.0

# %%
Y = train['CTC']
train.drop('CTC' , axis = 1 , inplace = True)
print(Y)
# Out:
# 0       0.261181
# 1       0.212873
# 2       0.337284
# 3       0.412975
# 4       0.296289
#           ...
# 1333    0.237115
# 1334    0.231239
# 1335    0.190030
# 1336    0.156599
# 1337    0.430784
# Name: CTC, Length: 1338, dtype: float64

# %%
X= train.iloc[:,:]
print(X)
# Out:
#       College  Role  Previous CTC  Previous job changes  Graduation marks  \
# 0         1.0   0.0      0.452897              0.666667              0.62
# 1         0.5   1.0      0.490970              0.000000              0.98
# 2         0.5   1.0      0.570783              0.333333              0.34
# 3         0.0   1.0      0.293737              0.333333              0.92
# 4         0.0   1.0      0.510471              1.000000              0.78
# ...       ...   ...           ...                   ...               ...
# 1333      0.0   1.0      0.554019              1.000000              0.66
# 1334      1.0   1.0      0.408690              0.000000              0.64
# 1335      0.5   1.0      0.610127              0.000000              0.24
# 1336      1.0   1.0      0.396202              0.666667              0.68
# 1337      0.0   0.0      0.362406              0.000000              0.24
#
#       Exp (Months)  Metro  Non-Metro
# 0         0.021739    0.0        1.0
# ...

# %%
X.shape
# Out:
# (1338, 8)

# %%
Y.shape
# Out:
# (1338,)

# %%
# from sklearn.model_selection import train_test_split
# x_train , x_test , y_train , y_test = train_test_split(X,Y)

# %%
x_train , y_train = X,Y

# %%
print(x_train.shape , y_train.shape)
# Out:
# (1338, 8) (1338,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
# x_train.reshape(-1,1)
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
test.head(2)
# Out:
#    College  Role  previous CTC  previous job changes  Graduation marks  \
# 0      1.0   0.0      0.452897              0.666667              0.62
# 1      0.5   1.0      0.490970              0.000000              0.98
#
#         Exp  Actual CTC  Metro  Non-Metro
# 0  0.021739    0.261181    0.0        1.0
# 1  0.000000    0.212873    1.0        0.0

# %%
test.rename(columns = {'Exp':'Exp (Months)'}, inplace = True)
test.rename(columns = {'previous CTC':'Previous CTC'}, inplace = True)
test.rename(columns = {'previous job changes':'Previous job changes'}, inplace = True)

# %%
y_test = test['Actual CTC']
test.drop('Actual CTC' , axis = 1 , inplace = True)
x_test = test.iloc[:,:]

# %%
print(x_test.shape , y_test.shape)
# Out:
# (1338, 8) (1338,)

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# **MSE**

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test , y_pred)
# Out:
# 0.012807828552539507

# %% [markdown]
# PLOTTING FIRST 100 PRED AND ACTUAL VALUES

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline


def plotGraph(y_test,y_pred,regressorName):
    if max(y_test) >= max(y_pred):
        my_range = int(max(y_test))
    else:
        my_range = int(max(y_pred))
    plt.figure(figsize = (17,11))
    plt.plot(range(len(y_test)), y_test, color='blue', label = 'Actual')
    plt.plot(range(len(y_pred)), y_pred, color='red' , label = 'Predicted' )
    plt.legend()
    plt.xlabel('candidates')
    plt.ylabel('ctc')
    plt.title(regressorName)
    plt.show()
    return

plotGraph(y_test[:100], y_pred[:100], "test")
